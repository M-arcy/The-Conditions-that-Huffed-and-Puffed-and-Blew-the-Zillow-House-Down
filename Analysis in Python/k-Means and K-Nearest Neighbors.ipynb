# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
from sklearn import metrics
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
# Original data from Kaggle: https://www.kaggle.com/marcopale/housing/
# Place train.csv in the Train_and_test sets/ folder before running
house = pd.read_csv("../Train_and_test sets/train.csv")
test = pd.read_csv("../Train_and_test sets/test.csv")

# %%
house.drop(columns= ['Id', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'MasVnrArea', 'BsmtExposure', 'PoolQC', 'MiscFeature', 'MoSold', 'YrSold', 'SaleType', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'Fence'], axis=1, inplace=True)

# %%
list1= house.select_dtypes("O")
list_objects = []
for i in list1:
    list_objects.append(i)
    
    
    
for i in list_objects:
    house[i] = le.fit_transform(house[i])

# %%
house[['Exterior1st', 'Exterior2nd', 'MasVnrType', 'BsmtFinSF2', 'BsmtUnfSF', 'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual', 'Functional', 'GarageCars', 'GarageArea',  'BsmtQual', 'BsmtCond',  'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageQual', 'LotFrontage', 'GarageCond']] = house[['Exterior1st', 'Exterior2nd', 'MasVnrType', 'BsmtFinSF2', 'BsmtUnfSF', 'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual', 'Functional', 'GarageCars', 'GarageArea' , 'BsmtQual', 'BsmtCond',  'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageQual', 'LotFrontage', 'GarageCond']].fillna(value=0)

# %%
house.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# SaleCondition    0
# SalePrice        0
# Length: 61, dtype: int64

# %%
pd.set_option("display.max_rows",90)
house.isna().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotConfig        0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# FireplaceQu      0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# SaleCondition    0
# SalePrice        0
# dtype: int64

# %%
house.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('int32'), dtype('float64')], dtype=object)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(house)
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# #### Summary
# This notebook applied K-Means clustering (n_clusters=2) to the cleaned housing dataset to group homes into two broad market segments — higher-value and lower-value properties. The clusters were then visualized against key features from the stepwise regression analysis (OverallQual, YearBuilt, GrLivArea) to see whether the unsupervised groupings aligned with the price-driving variables identified in R.
#
# The KFold cross-validation setup prepared for KNN classification but the primary modeling and evaluation is carried out in the main exploratory notebook.
